ives charniers et ossuaires. Ce n’est que plus tard, à la veille de la Révolution, quand certaines de ces fosses communes se furent dangereusement effondrées et que la puanteur de ce cimetière débordant déclencha chez les riverains non plus de simples protestations, mais de véritables émeutes, qu’on finit par le fermer et par l’éventrer, et qu’on pelleta des millions d’ossements et de crânes en direction des catacombes de Montmartre, et qu’on édifia sur les lieux une place de marché. Or c’est là, à l’endroit le plus puant de tout le royaume, que vit le jour, le 17 juillet 1738, Jean Baptiste Grenouille."

# %%
nltk.word_tokenize(phrase) # tokenize la phrase en mots
# Out:
# ['Au',
#  'XVIIIe',
#  'siècle',
#  'vécut',
#  'en',
#  'France',
#  'un',
#  'homme',
#  'qui',
#  'compta',
#  'parmi',
#  'les',
#  'personnages',
#  'les',
#  'plus',
#  'géniaux',
#  'et',
#  'les',
#  'plus',
#  'abominables',
#  'de',
#  'cette',
#  'époque',
#  'qui',
#  'pourtant',
#  'ne',
#  'manqua',
#  'pas',
#  'de',
#  'génies',
#  'abominables',
#  '.',
#  'C',
#  '’',
#  'est',
#  'son',
#  'histoire',
#  'qu',
#  '’',
#  'il',
#  's',
#  '’',
#  'agit',
#  'de',
#  'raconter',
#  'ici',
#  '.',
#  'Il',
#  's',
#  '’',
#  'appelait',
#  'Jean-Baptiste',
#  'Grenouille',
#  'et',
#  'si',
#  'son',
#  'nom',
#  ',',
#  'à',
#  'la',
#  'différence',
#  'de',
#  'ceux',
#  'd',
#  '’',
#  'autres',
#  'scélérats',
#  'de',
#  'génie',
#  'comme',
#  'par',
#  'exemple',
#  'Sade',
#  ',',
#  'Saint-Just',
#  ',',
#  'Fouché',
#  ',',
#  'Bonaparte',
#  ',',
#  'etc.',
#  ',',
#  'est',
#  'aujourd',
#  '’',
#  'hui',
#  'tombé',
#  'dans',
#  'l',
#  '’',
# ...

# %%
nltk.sent_tokenize(phrase) # tokenize la phrase en phrases
# Out:
# ['Au XVIIIe siècle vécut en France un homme qui compta parmi les personnages les plus géniaux et les plus abominables de cette époque qui pourtant ne manqua pas de génies abominables.',
#  'C’est son histoire qu’il s’agit de raconter ici.',
#  'Il s’appelait Jean-Baptiste Grenouille et si son nom, à la différence de ceux d’autres scélérats de génie comme par exemple Sade, Saint-Just, Fouché, Bonaparte, etc., est aujourd’hui tombé dans l’oubli, ce n’est assurément pas que Grenouille fût moins bouffi d’orgueil, moins ennemi de l’humanité, moins immoral, en un mot moins impie que ces malfaisants plus illustres, mais c’est que son génie et son unique ambition se bornèrent à un domaine qui ne laisse point de traces dans l’histoire\xa0: au royaume évanescent des odeurs.',
#  'A l’époque dont nous parlons, il régnait dans les villes une puanteur à peine imaginable pour les modernes que nous sommes.',
# ...

# %%
nltk.corpus.stopwords.words("french") # On affiche les mots vides (stopwords) en français
# Out:
# ['au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
# ...

# %%
tokens = nltk.word_tokenize(phrase.lower()) # On tokenize la phrase en mots et on met tout en minuscule pour éviter les stopwords avec majuscules.

tokens_clean = [] # On crée une liste vide pour stocker les mots qui ne sont pas des stopwords
for words in tokens: # On parcourt tous les mots de phrase
  if words not in nltk.corpus.stopwords.words("french"):
    tokens_clean.append(words)

tokens_clean
# Out:
# ['xviiie',
#  'siècle',
#  'vécut',
#  'france',
#  'homme',
#  'compta',
#  'parmi',
#  'personnages',
#  'plus',
#  'géniaux',
#  'plus',
#  'abominables',
#  'cette',
#  'époque',
#  'pourtant',
#  'manqua',
#  'génies',
#  'abominables',
#  '.',
#  '’',
#  'histoire',
#  '’',
#  '’',
#  'agit',
#  'raconter',
#  'ici',
#  '.',
#  '’',
#  'appelait',
#  'jean-baptiste',
#  'grenouille',
#  'si',
#  'nom',
#  ',',
#  'différence',
#  'ceux',
#  '’',
#  'autres',
#  'scélérats',
#  'génie',
#  'comme',
#  'exemple',
#  'sade',
#  ',',
#  'saint-just',
#  ',',
#  'fouché',
#  ',',
#  'bonaparte',
#  ',',
#  'etc.',
#  ',',
#  'aujourd',
#  '’',
#  'hui',
#  'tombé',
#  '’',
#  'oubli',
#  ',',
#  '’',
#  'assurément',
#  'grenouille',
#  'moins',
#  'bouffi',
#  '’',
#  'orgueil',
#  ',',
#  'moins',
#  'ennemi',
#  '’',
#  'humanité',
#  ',',
#  'moins',
#  'immoral',
#  ',',
#  'mot',
#  'moins',
#  'impie',
#  'malfaisants',
#  'plus',
#  'illustres',
#  ',',
#  '’',
#  'génie',
# ...

# %%
nltk.FreqDist(nltk.word_tokenize(phrase)) # On compte le nombre d'occurences de chaque mot dans la phrase
# Out:
# FreqDist({',': 53, '’': 35, 'de': 30, 'les': 26, 'et': 23, 'la': 21, 'le': 16, '.': 15, 'puaient': 12, 'l': 10, ...})

# %%
#Stemming
stem_en = SnowballStemmer("french")
for word in nltk.word_tokenize(phrase):
  print(stem_en.stem(word))
# Out:
# au
# xvii
# siecl
# vécut
# en
# franc
# un
# homm
# qui
# compt
# parm
# le
# personnag
# le
# plus
# génial
# et
# le
# plus
# abomin
# de
# cet
# époqu
# qui
# pourt
# ne
# manqu
# pas
# de
# gen
# abomin
# .
# c
# ’
# est
# son
# histoir
# qu
# ’
# il
# s
# ’
# agit
# de
# racont
# ici
# .
# il
# s
# ’
# appel
# jean-bapt
# grenouill
# et
# si
# son
# nom
# ,
# à
# la
# différent
# de
# ceux
# d
# ’
# autr
# scélérat
# de
# gen
# comm
# par
# exempl
# sad
# ,
# saint-just
# ,
# fouch
# ,
# bonapart
# ,
# etc.
# ,
# est
# aujourd
# ’
# hui
# tomb
# dan
# l
# ’
# oubl
# ,
# ce
# n
# ’
# est
# assur
# pas
# que
# grenouill
# fût
# moin
# bouff
# d
# ’
# orgueil
# ,
# moin
# ennem
# de
# l
# ’
# human
# ,
# moin
# immoral
# ,
# en
# un
# mot
# moin
# impi
# que
# ce
# malfais
# plus
# illustr
# ,
# mais
# c
# ’
# est
# que
# son
# gen
# et
# son
# uniqu
# ambit
# se
# born
# à
# un
# domain
# qui
# ne
# laiss
# point
# de
# trac
# dan
# l
# ’
# histoir
# :
# au
# royaum
# évanescent
# ...

# %%
 # On affiche la racine de chaque mot de la phrase via une compréhension de liste que l'on met dans une variable.
sent_stem  = [stem_en.stem(word) for word in nltk.word_tokenize(phrase)]
nltk.FreqDist(sent_stem)
# Out:
# FreqDist({',': 53, 'le': 47, 'de': 37, '’': 35, 'et': 25, 'la': 21, 'pu': 18, '.': 15, 'l': 10, 'plus': 9, ...})

# %%
#Lemmatization

# Import des règles françaises de spacy
nlp = spacy.load('fr_core_news_sm')

# spacy découpe automatiquement en tokens avec cette syntaxe :
sent_tokens = nlp(phrase)

for token in sent_tokens:
    print(token, token.lemma_)
# Out:
# Au au
# XVIIIe xviii
# siècle siècle
# vécut vécut
# en en
# France France
# un un
# homme homme
# qui qui
# compta compter
# parmi parmi
# les le
# personnages personnage
# les le
# plus plus
# géniaux génial
# et et
# les le
# plus plus
# abominables abominable
# de de
# cette ce
# époque époque
# qui qui
# pourtant pourtant
# ne ne
# manqua manquer
# pas pas
# de de
# génies génie
# abominables abominable
# . .
# C’ c’
# est être
# son son
# histoire histoire
# qu’ qu’
# il il
# s’ s’
# agit agir
# de de
# raconter raconter
# ici ici
# . .
# Il il
# s’ s’
# appelait appeler
# Jean-Baptiste Jean-Baptiste
# Grenouille Grenouille
# et et
# si si
# son son
# nom nom
# , ,
# à à
# la le
# différence différence
# de de
# ceux celui
# d’ d’
# autres autre
# scélérats scélérat
# de de
# génie génie
# comme comme
# par par
# exemple exemple
# Sade Sade
# , ,
# Saint-Just Saint-Just
# , ,
# Fouché Fouché
# , ,
# Bonaparte Bonaparte
# , ,
# etc. etc.
# , ,
# est être
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=480, height=480, max_font_size=200, min_font_size=10)

#Retirer la ponctuation
sent_tokens = [token for token in sent_tokens if not token.is_punct]

#Retirer les stopwords
sent_tokens = [token for token in sent_tokens if not token.is_stop]

# Génération du wordcloud depuis un texte
dico = nltk.FreqDist([token.lemma_ for token in sent_tokens])
wordcloud.generate_from_frequencies(dico)

# Affichage grâce à Matplotlib
plt.figure(figsize=[4,8])
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
meta_mask = np.array(Image.open('Parfum.jpg'))
meta_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
wc = WordCloud(background_color='black', mask=meta_mask, contour_width=2,
               contour_color='black', colormap='BuPu_r', width=800, height=500).generate_from_frequencies(dico)
plt.axis("off")
plt.imshow(wc)
